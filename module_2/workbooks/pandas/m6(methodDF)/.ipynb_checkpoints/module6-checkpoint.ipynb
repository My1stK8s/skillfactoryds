# %%
import pandas as pd
df = pd.read_csv('/home/ssmd/Документы/pandas/m6(methodDF)/data_sf.csv') 
df
# ВИДИШЬ СУКА ОН  ОГРОМНЫЙ  И ВЕСЬ  НА СТРАНИЦУ НЕ  ЛЕЗЕТ 
# МНЕ НУЖНА  ЧАСТЬ  ВОТ Я ЕЕ  ЗАДАЛ ниже  8 колонок 25  строк 
small_football = df[df.columns[1:8]].head(25)
small_football
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df['Age'].value_counts()
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5841f77f6fd8> in <module>
# ----> 1 s = small_df['Age'].value_counts()
#       2 s
#
# NameError: name 'small_df' is not defined

# %%
s = small_df['Age'].value_counts(normalize=True)
s

# %%
fb = df
fb
fb.describe(include = ['object'])
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(fb.head(10))
fb.describe()

# %%
s = small_df['Age'].value_counts(bins=4)
display(s)

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]

# %%
s.index[3].left

# %%
s.index[3].right

# %%
# df.loc[(df['FKAccuracy'] > s.index[-1].left) & (df['FKAccuracy'] <= s.index[-3].right)]

# %%
# fk = df['FKAccuracy'].value_counts()
# fk = df['FKAccuracy'].value_counts(normalize=True)

fk = df['FKAccuracy'].value_counts(bins= 5)
fk

# %%
df
df['Nationality'].nunique()

# %%
# result = len(df['Position'].unique())
# result = df['Position'].unique()
# result = df['Position'].count()
result = len(df['Position'].value_counts())
result

# %%
import pandas as pd
df = pd.read_csv('/home/ssmd/Документы/pandas/data_sf.csv') 
# fk = df['Nationality'].value_counts()
df[df.Nationality == 'Spain'].Wage.value_counts(normalize=True, bins=4)

# %%
df[df.Club == 'Manchester United'].Nationality.unique()

# %%
df[(df.Club == 'Juventus') & (df.Nationality == 'Brazil')].Name.unique()

# %%
df[df.Age > 35].Club.value_counts().loc['Club Atlético Huracán']

# %%
df[df.Nationality == 'Argentina'].Age.value_counts(bins=4)

# %%
df[(df.Nationality == 'Spain')].Age.value_counts(normalize=True).loc[21]
#    & (df.Age == 21)].Age(21).value_counts(normalize=True)

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().head(25)
display(grouped_df)

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False).head(25)
grouped_df
# Out:
# Club
# Real Madrid            4138000
# FC Barcelona           3967000
# Manchester City        3097000
# Manchester United      2357000
# Juventus               2335000
# Liverpool              2163000
# FC Bayern München      2051000
# Chelsea                2035000
# Tottenham Hotspur      1841000
# Arsenal                1795000
# Paris Saint-Germain    1620000
# West Ham United        1221000
# Atlético Madrid        1143000
# Milan                  1134000
# Napoli                 1042000
# Everton                1014000
# Inter                   949000
# Roma                    854000
# Borussia Dortmund       789000
# AS Monaco               770000
# Leicester City          744000
# Bayer 04 Leverkusen     684000
# Lazio                   628000
# Burnley                 606000
# Olympique Lyonnais      580000
# Name: Wage, dtype: int64

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)

# %%
df.loc[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]

# %%
df.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False).head(10)

# %%
# s = [df.groupby(['Club'])['Wage'].mean() == df.groupby(['Club'])['Wage'].median()].unique()
# #     if i == True:
#         print(s.loc['Club'])
# gg
gg = df.groupby(['Club'])['Wage'].agg(['mean','median'])

# gg(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False).head(10)
gg = gg.reset_index()
gg = gg[gg['mean'] == gg['median']].Club
gg
# gg = gg.groupby(['Club'])[['mean','median']].max().sort_values(['mean'],ascending=False)
gg

# %%
gg=df.groupby(['Club'])['Wage'].agg(['mean','median'])
gg
# gg[gg['mean'] == gg['median']])
# gg=gg[gg['mean'] == gg['median']].max()
# gg.iloc[0]

# %%
gg = df.groupby(['Club'])['Wage'].agg(['mean','median'])

# gg
gg = gg[gg['mean'] == gg['median']].sort_values(['mean'],ascending=False)
gg = gg.reset_index()
gg

# %%
# gg=gg[gg['mean'] == gg['median']].Club.max()

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
# grouped_df = grouped_df['Club' == 'Chelsea']
grouped_df['Chelsea']

# %%
df[(df.Age == 30)]
# Out:
#        Unnamed: 0          Name  Age          Nationality              Club  \
# 23             23     S. Agüero   30            Argentina   Manchester City
# 35             35       Marcelo   30               Brazil       Real Madrid
# 38             38    G. Higuaín   30            Argentina             Milan
# 52             52     M. Hamšík   30             Slovakia            Napoli
# 53             53    I. Rakitić   30              Croatia      FC Barcelona
# ...           ...           ...  ...                  ...               ...
# 11070       11291    P. O'Conor   30  Republic of Ireland    Bray Wanderers
# 11684       11909  Zhu Xiaogang   30             China PR  Dalian YiFang FC
# 11770       11997   J. Sinclair   30              England         Morecambe
# 12550       12779     A. Ekblad   30               Sweden        Dalkurd FF
# 12552       12781      P. Azizi   30               Sweden        Dalkurd FF
#
# ...

# %%
df[(df.Club == 'FC Barcelona') & (df.Nationality == 'Argentina')].Strength.max()
df[(df.Club == 'FC Barcelona') & (df.Nationality == 'Argentina')].Balance.max()

# %%
df[(df.Club == 'FC Barcelona') & (df.Nationality == 'Argentina')][['Strength', 'Balance']].max()

# %%
pivot = df.loc[df['Club'].isin(['AS Monaco'])].pivot_table(values='Wage',
index='Nationality',
columns='Club')

# aggfunc='sum')
display(pivot)

# %%
pivot['Russia']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-106f1e9359a0> in <module>
# ----> 1 pivot['Russia']
#
# NameError: name 'pivot' is not defined

# %%
pivo = df.pivot_table(
values='SprintSpeed',
index=['Club'],
columns=['Position'],
aggfunc='mean',
fill_value=0)
pivo['ST'].sort_values(ascending=False)

# %%
pivo['GK']

# %%
pivo['CM'].value_counts()

# %%
pivot = df.pivot_table(columns='Position', index = 'Club', values = 'Name', aggfunc='count', fill_value=0)
pivot

# %%
pivot['CM'].value_counts()

# %%
pivot = df.loc[df['Name'].isin([])].pivot_table(values='Positions',
index='Nationality',
columns='Posinion,
aggfunc='sum')
display(pivot)

# %%
pivot = df.pivot_table(columns='Position', index = 'Name', values = 'SprintSpeed', aggfunc='sum', fill_value=0)
pivot

# %%
df.info()

# %%
pivot = df.loc[df['Position'].isin(['ST'])].pivot_table(values=['SprintSpeed'],
index=['Club','Name'],
columns=['Position'],
aggfunc=['mean'],
fill_value=0)
display(pivot)
# pivot['ST'].sort_values(ascending=False)

# %%
df = pd.read_csv('data_sf.csv')
pivot = df.pivot_table(values=['SprintSpeed'],
                       index=['Club'],
                       columns=['Position'],
                       aggfunc='mean',
                       margins=True,
                       fill_value=0)
pivot['SprintSpeed'].max()
# pivot.max().sort_values(ascending=False)

# %%
pivot = df.loc[df['Position'].isin(['RB','LM','RM','CF','RWM','RS'])].pivot_table(values=['SprintSpeed'],
index=['Club'],
columns=['Position'],
aggfunc=['mean'],
fill_value=0)
display(pivot)
co = len(df['Club'].value_counts())
na = len(df['Name'].value_counts())
display(co)
# result = len(df['Position'].value_counts())
# pivot.max().sort_values(ascending=False)
df.info()
